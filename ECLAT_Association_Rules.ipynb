# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df=pd.read_csv("/content/drive/MyDrive/Market_Basket_Optimisation.csv",header=None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
# !pip install pyECLAT

# %%
from pyECLAT import ECLAT

# %%
eclat_instance =ECLAT(data=df,verbose=True)
# Out:
# ...
# 100%|██████████| 120/120 [00:00<00:00, 2785.93it/s]

# %%
eclat_instance.uniq_
# Out:
# ['green grapes',
#  'cereals',
#  'parmesan cheese',
#  'whole weat flour',
#  'whole wheat rice',
#  'rice',
#  'mashed potato',
#  'fresh tuna',
#  'water spray',
#  'sparkling water',
#  'mineral water',
#  'energy bar',
#  'chocolate',
#  'escalope',
#  'eggs',
#  'champagne',
#  'turkey',
#  'burger sauce',
#  'energy drink',
#  'cookies',
#  'protein bar',
#  'milk',
#  'soup',
#  'carrots',
#  'chicken',
#  'blueberries',
#  'tomato juice',
#  'napkins',
#  'clothes accessories',
#  'ground beef',
#  'cottage cheese',
#  'babies food',
#  'body spray',
#  'pickles',
#  ' asparagus',
#  'hot dogs',
#  'honey',
#  'almonds',
#  'shallot',
#  'herb & pepper',
#  'eggplant',
#  'mint green tea',
#  'oil',
#  'muffins',
#  'tomatoes',
#  'oatmeal',
#  'magazines',
#  'mint',
#  'mayonnaise',
#  'pasta',
#  'fromage blanc',
#  'strawberries',
#  'fresh bread',
#  'bacon',
#  'pet food',
#  'brownies',
#  'zucchini',
#  'hand protein bar',
#  'cream',
#  'pancakes',
# ...

# %%
get_ECLAT_indexes,get_ECLAT_supports=eclat_instance.fit(min_support=0.02,min_combination=1,max_combination=3,separator='&',verbose=True)
# Out:
# Combination 1 by 1
# 53it [00:02, 24.62it/s]
# Combination 2 by 2
# 1378it [00:28, 48.27it/s]
# Combination 3 by 3
# 23426it [08:00, 48.80it/s]
